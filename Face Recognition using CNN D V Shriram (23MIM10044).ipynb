# %% [markdown]
# # Face Recognition using CNN — Labeled Faces in the Wild (LFW)
#
# **Name:** D V Shriram
# **Reg No:** 23MIM10044
#
# **Objective:** Build a CNN model to recognize faces from the LFW dataset with a target accuracy of 90%.
#
# **Dataset:** LFW (Labeled Faces in the Wild) — 1,288 grayscale images of 7 public figures, 50×37 pixels

# %%
# installing all the required libraries
# !pip install tensorflow matplotlib numpy scipy scikit-learn seaborn
# Out:
# Requirement already satisfied: tensorflow in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.21.0)
# Requirement already satisfied: matplotlib in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.11.0)
# Requirement already satisfied: numpy in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.5.0)
# Requirement already satisfied: scipy in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.18.0)
# Requirement already satisfied: scikit-learn in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.9.0)
# Requirement already satisfied: seaborn in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: keras>=3.12.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=9 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.4.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: tzdata in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
# importing the necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %%
# loading LFW dataset - keeping only people with at least 70 images
lfw = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

print("Dataset shape:", lfw.images.shape)
print("Number of classes (people):", lfw.target_names.shape[0])
print("People in dataset:", lfw.target_names)
# Out:
# Dataset shape: (1288, 50, 37)
# Number of classes (people): 7
# People in dataset: ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']

# %%
# checking how many images each person has
print("Number of images per person:")
for i, name in enumerate(lfw.target_names):
    count = np.sum(lfw.target == i)
    print(f"  {name}: {count} images")

# visualizing some sample faces
plt.figure(figsize=(12, 8))
for i in range(14):
    plt.subplot(2, 7, i+1)
    plt.imshow(lfw.images[i * 90], cmap='gray')
    plt.title(lfw.target_names[lfw.target[i * 90]].split()[-1], fontsize=9)
    plt.xticks([])
    plt.yticks([])
plt.suptitle("Sample Faces from LFW Dataset", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Number of images per person:
#   Ariel Sharon: 77 images
#   Colin Powell: 236 images
#   Donald Rumsfeld: 121 images
#   George W Bush: 530 images
#   Gerhard Schroeder: 109 images
#   Hugo Chavez: 71 images
#   Tony Blair: 144 images

# %%
# preprocessing the data
x = lfw.images
y = lfw.target

# sklearn already gives pixel values between 0 and 1, so no need to divide by 255
print("Pixel range - Min:", x.min(), "Max:", x.max())

# adding channel dimension for CNN (grayscale = 1 channel)
x = x.reshape(-1, 50, 37, 1)

# splitting into train and test (80-20 split)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Pixel range - Min: 0.0 Max: 1.0
# Training data shape: (1030, 50, 37, 1)
# Test data shape: (258, 50, 37, 1)

# %%
# building the CNN model for face recognition
model = models.Sequential([
    # first conv block - 32 filters
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(50, 37, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # second conv block - 64 filters
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # third conv block - 128 filters
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # dense layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),

    # output layer - 7 people so 7 neurons with softmax
    layers.Dense(7, activation='softmax')
])

model.summary()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 50, 37, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 50, 37, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 25, 18, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 25, 18, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 25, 18, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 25, 18, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 9, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 9, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 9, 128)          │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 9, 128)          │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         393,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 487,815 (1.86 MB)
#  Trainable params: 487,367 (1.86 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# data augmentation - important since we have limited training data
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)
datagen.fit(x_train)

# compiling with adam optimizer
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# callbacks - reduce lr when accuracy plateaus and early stopping
lr_reducer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=8, min_lr=1e-6, verbose=1, mode='max')
early_stop = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True, verbose=1, mode='max')

# training with data augmentation
history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=80,
                    validation_data=(x_test, y_test),
                    callbacks=[lr_reducer, early_stop])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.2893 - loss: 2.4896 - val_accuracy: 0.1124 - val_loss: 3.9677 - learning_rate: 0.0010
# Epoch 2/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3864 - loss: 1.7680 - val_accuracy: 0.0698 - val_loss: 6.1314 - learning_rate: 0.0010
# Epoch 3/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.3942 - loss: 1.7282 - val_accuracy: 0.1008 - val_loss: 6.8063 - learning_rate: 0.0010
# Epoch 4/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.4359 - loss: 1.6041 - val_accuracy: 0.1124 - val_loss: 7.3316 - learning_rate: 0.0010
# Epoch 5/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4408 - loss: 1.5983 - val_accuracy: 0.1357 - val_loss: 6.8149 - learning_rate: 0.0010
# Epoch 6/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4553 - loss: 1.5869 - val_accuracy: 0.1899 - val_loss: 4.6853 - learning_rate: 0.0010
# Epoch 7/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4495 - loss: 1.5646 - val_accuracy: 0.2132 - val_loss: 4.8516 - learning_rate: 0.0010
# Epoch 8/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4835 - loss: 1.4249 - val_accuracy: 0.1008 - val_loss: 3.4205 - learning_rate: 0.0010
# Epoch 9/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5078 - loss: 1.3837 - val_accuracy: 0.5194 - val_loss: 2.1749 - learning_rate: 0.0010
# Epoch 10/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4903 - loss: 1.3979 - val_accuracy: 0.4612 - val_loss: 2.2295 - learning_rate: 0.0010
# Epoch 11/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5184 - loss: 1.2873 - val_accuracy: 0.4574 - val_loss: 2.5642 - learning_rate: 0.0010
# Epoch 12/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5320 - loss: 1.2793 - val_accuracy: 0.4341 - val_loss: 3.0260 - learning_rate: 0.0010
# Epoch 13/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5379 - loss: 1.2451 - val_accuracy: 0.4651 - val_loss: 2.1286 - learning_rate: 0.0010
# Epoch 14/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5350 - loss: 1.2740 - val_accuracy: 0.5581 - val_loss: 1.4700 - learning_rate: 0.0010
# Epoch 15/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5388 - loss: 1.2400 - val_accuracy: 0.5814 - val_loss: 1.5931 - learning_rate: 0.0010
# Epoch 16/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5670 - loss: 1.1715 - val_accuracy: 0.6163 - val_loss: 1.3523 - learning_rate: 0.0010
# Epoch 17/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6000 - loss: 1.1448 - val_accuracy: 0.6085 - val_loss: 1.2494 - learning_rate: 0.0010
# Epoch 18/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5825 - loss: 1.0806 - val_accuracy: 0.5891 - val_loss: 1.4048 - learning_rate: 0.0010
# Epoch 19/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6184 - loss: 1.0723 - val_accuracy: 0.6589 - val_loss: 1.0481 - learning_rate: 0.0010
# Epoch 20/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6029 - loss: 1.0590 - val_accuracy: 0.3333 - val_loss: 2.7122 - learning_rate: 0.0010
# Epoch 21/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6184 - loss: 1.0369 - val_accuracy: 0.6318 - val_loss: 1.0612 - learning_rate: 0.0010
# Epoch 22/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6369 - loss: 0.9719 - val_accuracy: 0.7016 - val_loss: 0.7426 - learning_rate: 0.0010
# Epoch 23/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6515 - loss: 0.9764 - val_accuracy: 0.4651 - val_loss: 1.5617 - learning_rate: 0.0010
# Epoch 24/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6631 - loss: 0.9272 - val_accuracy: 0.7054 - val_loss: 0.7603 - learning_rate: 0.0010
# Epoch 25/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6417 - loss: 0.9724 - val_accuracy: 0.6589 - val_loss: 0.8960 - learning_rate: 0.0010
# Epoch 26/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6738 - loss: 0.8708 - val_accuracy: 0.6938 - val_loss: 1.0306 - learning_rate: 0.0010
# Epoch 27/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6495 - loss: 0.9207 - val_accuracy: 0.7907 - val_loss: 0.6236 - learning_rate: 0.0010
# Epoch 28/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6777 - loss: 0.9090 - val_accuracy: 0.4302 - val_loss: 1.6209 - learning_rate: 0.0010
# Epoch 29/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6951 - loss: 0.8614 - val_accuracy: 0.7171 - val_loss: 0.7293 - learning_rate: 0.0010
# Epoch 30/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6806 - loss: 0.8558 - val_accuracy: 0.5930 - val_loss: 1.1948 - learning_rate: 0.0010
# Epoch 31/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6544 - loss: 0.9443 - val_accuracy: 0.7791 - val_loss: 0.5741 - learning_rate: 0.0010
# Epoch 32/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6699 - loss: 0.8931 - val_accuracy: 0.7403 - val_loss: 0.8978 - learning_rate: 0.0010
# Epoch 33/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7058 - loss: 0.8200 - val_accuracy: 0.8062 - val_loss: 0.5373 - learning_rate: 0.0010
# Epoch 34/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6942 - loss: 0.8336 - val_accuracy: 0.2868 - val_loss: 2.7406 - learning_rate: 0.0010
# Epoch 35/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7029 - loss: 0.8135 - val_accuracy: 0.4884 - val_loss: 1.4768 - learning_rate: 0.0010
# Epoch 36/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7350 - loss: 0.7345 - val_accuracy: 0.5039 - val_loss: 1.5591 - learning_rate: 0.0010
# Epoch 37/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7291 - loss: 0.7599 - val_accuracy: 0.8566 - val_loss: 0.4051 - learning_rate: 0.0010
# Epoch 38/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7311 - loss: 0.7371 - val_accuracy: 0.6085 - val_loss: 1.2059 - learning_rate: 0.0010
# Epoch 39/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7447 - loss: 0.7561 - val_accuracy: 0.8062 - val_loss: 0.6394 - learning_rate: 0.0010
# Epoch 40/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7485 - loss: 0.7407 - val_accuracy: 0.6977 - val_loss: 1.1827 - learning_rate: 0.0010
# Epoch 41/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7456 - loss: 0.7297 - val_accuracy: 0.7093 - val_loss: 1.0387 - learning_rate: 0.0010
# Epoch 42/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7495 - loss: 0.7009 - val_accuracy: 0.7868 - val_loss: 0.6760 - learning_rate: 0.0010
# Epoch 43/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7350 - loss: 0.7349 - val_accuracy: 0.8760 - val_loss: 0.3665 - learning_rate: 0.0010
# Epoch 44/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7845 - loss: 0.6714 - val_accuracy: 0.8760 - val_loss: 0.3813 - learning_rate: 0.0010
# Epoch 45/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7796 - loss: 0.6420 - val_accuracy: 0.8411 - val_loss: 0.4805 - learning_rate: 0.0010
# Epoch 46/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7796 - loss: 0.6588 - val_accuracy: 0.8915 - val_loss: 0.3970 - learning_rate: 0.0010
# Epoch 47/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7893 - loss: 0.6541 - val_accuracy: 0.8643 - val_loss: 0.4505 - learning_rate: 0.0010
# Epoch 48/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7883 - loss: 0.6175 - val_accuracy: 0.9225 - val_loss: 0.2195 - learning_rate: 0.0010
# Epoch 49/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7922 - loss: 0.5736 - val_accuracy: 0.8915 - val_loss: 0.3994 - learning_rate: 0.0010
# Epoch 50/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7845 - loss: 0.6282 - val_accuracy: 0.8915 - val_loss: 0.4345 - learning_rate: 0.0010
# Epoch 51/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7718 - loss: 0.6489 - val_accuracy: 0.8372 - val_loss: 0.5717 - learning_rate: 0.0010
# Epoch 52/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7913 - loss: 0.5983 - val_accuracy: 0.8643 - val_loss: 0.4171 - learning_rate: 0.0010
# Epoch 53/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8049 - loss: 0.5813 - val_accuracy: 0.8682 - val_loss: 0.3844 - learning_rate: 0.0010
# Epoch 54/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7981 - loss: 0.5681 - val_accuracy: 0.9031 - val_loss: 0.2965 - learning_rate: 0.0010
# Epoch 55/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8126 - loss: 0.5734 - val_accuracy: 0.8527 - val_loss: 0.4303 - learning_rate: 0.0010
# Epoch 56/80
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7986 - loss: 0.5178
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7971 - loss: 0.5206 - val_accuracy: 0.7674 - val_loss: 0.7073 - learning_rate: 0.0010
# Epoch 57/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8155 - loss: 0.5667 - val_accuracy: 0.9264 - val_loss: 0.2338 - learning_rate: 5.0000e-04
# Epoch 58/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8136 - loss: 0.5177 - val_accuracy: 0.9225 - val_loss: 0.2201 - learning_rate: 5.0000e-04
# Epoch 59/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8243 - loss: 0.5127 - val_accuracy: 0.9612 - val_loss: 0.1774 - learning_rate: 5.0000e-04
# Epoch 60/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8427 - loss: 0.4580 - val_accuracy: 0.9264 - val_loss: 0.2594 - learning_rate: 5.0000e-04
# Epoch 61/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8515 - loss: 0.4269 - val_accuracy: 0.8837 - val_loss: 0.4195 - learning_rate: 5.0000e-04
# Epoch 62/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8563 - loss: 0.4572 - val_accuracy: 0.9264 - val_loss: 0.2347 - learning_rate: 5.0000e-04
# Epoch 63/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8592 - loss: 0.4312 - val_accuracy: 0.9380 - val_loss: 0.2031 - learning_rate: 5.0000e-04
# Epoch 64/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8621 - loss: 0.3906 - val_accuracy: 0.9186 - val_loss: 0.2733 - learning_rate: 5.0000e-04
# Epoch 65/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8495 - loss: 0.4470 - val_accuracy: 0.9457 - val_loss: 0.2035 - learning_rate: 5.0000e-04
# Epoch 66/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8437 - loss: 0.4225 - val_accuracy: 0.9496 - val_loss: 0.1766 - learning_rate: 5.0000e-04
# Epoch 67/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8583 - loss: 0.4204
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8583 - loss: 0.4204 - val_accuracy: 0.9070 - val_loss: 0.2637 - learning_rate: 5.0000e-04
# Epoch 68/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8854 - loss: 0.3709 - val_accuracy: 0.9341 - val_loss: 0.1946 - learning_rate: 2.5000e-04
# Epoch 69/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8553 - loss: 0.4097 - val_accuracy: 0.9264 - val_loss: 0.2108 - learning_rate: 2.5000e-04
# Epoch 70/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8573 - loss: 0.3976 - val_accuracy: 0.9651 - val_loss: 0.1592 - learning_rate: 2.5000e-04
# Epoch 71/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8718 - loss: 0.3564 - val_accuracy: 0.9612 - val_loss: 0.1343 - learning_rate: 2.5000e-04
# Epoch 72/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8806 - loss: 0.3625 - val_accuracy: 0.9612 - val_loss: 0.1547 - learning_rate: 2.5000e-04
# Epoch 73/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8699 - loss: 0.3783 - val_accuracy: 0.9574 - val_loss: 0.1514 - learning_rate: 2.5000e-04
# Epoch 74/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8709 - loss: 0.3558 - val_accuracy: 0.9302 - val_loss: 0.2079 - learning_rate: 2.5000e-04
# Epoch 75/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8835 - loss: 0.3498 - val_accuracy: 0.9496 - val_loss: 0.1595 - learning_rate: 2.5000e-04
# Epoch 76/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8903 - loss: 0.3510 - val_accuracy: 0.9535 - val_loss: 0.1553 - learning_rate: 2.5000e-04
# Epoch 77/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8709 - loss: 0.3775 - val_accuracy: 0.9612 - val_loss: 0.1438 - learning_rate: 2.5000e-04
# Epoch 78/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8893 - loss: 0.3353 - val_accuracy: 0.9729 - val_loss: 0.1257 - learning_rate: 2.5000e-04
# Epoch 79/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8583 - loss: 0.4030 - val_accuracy: 0.9031 - val_loss: 0.3307 - learning_rate: 2.5000e-04
# Epoch 80/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8806 - loss: 0.3481 - val_accuracy: 0.8837 - val_loss: 0.3941 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 78.

# %%
# plotting accuracy and loss curves to check for overfitting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'], label='Training Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Training vs Validation Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

ax2.plot(history.history['loss'], label='Training Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Training vs Validation Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

print("\nFinal Training Accuracy: {:.2f}%".format(history.history['accuracy'][-1] * 100))
print("Final Validation Accuracy: {:.2f}%".format(history.history['val_accuracy'][-1] * 100))

if history.history['val_accuracy'][-1] >= history.history['accuracy'][-1]:
    print("\n✅ No overfitting detected - validation accuracy is >= training accuracy")
else:
    gap = history.history['accuracy'][-1] - history.history['val_accuracy'][-1]
    if gap < 0.05:
        print("\n✅ No significant overfitting - gap is only {:.2f}%".format(gap * 100))
    else:
        print("\n⚠️ Possible overfitting - gap is {:.2f}%".format(gap * 100))
# Out:
# Final Training Accuracy: 88.06%
# Final Validation Accuracy: 88.37%
#
# ✅ No overfitting detected - validation accuracy is >= training accuracy

# %%
# evaluating on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)
print("\nTest Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test Loss: {:.4f}".format(test_loss))

# visualizing some predictions
predictions = model.predict(x_test[:15])

plt.figure(figsize=(15, 9))
for i in range(15):
    plt.subplot(3, 5, i+1)
    plt.imshow(x_test[i].reshape(50, 37), cmap='gray')
    predicted = lfw.target_names[np.argmax(predictions[i])].split()[-1]
    actual = lfw.target_names[y_test[i]].split()[-1]
    color = 'green' if predicted == actual else 'red'
    plt.xlabel(f"Pred: {predicted}\nActual: {actual}", color=color, fontsize=8)
    plt.xticks([])
    plt.yticks([])
plt.suptitle("Face Recognition Predictions (Green = Correct, Red = Wrong)", fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9729 - loss: 0.1257
#
# Test Accuracy: 97.29%
# Test Loss: 0.1257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step

# %%
# classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

y_pred = np.argmax(model.predict(x_test), axis=1)
short_names = [name.split()[-1] for name in lfw.target_names]

print("Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=short_names))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=short_names, yticklabels=short_names)
plt.title('Confusion Matrix - LFW Face Recognition')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("\n✅ Final Test Accuracy: {:.2f}% (Target was 90%)".format(test_accuracy * 100))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Sharon       0.94      0.94      0.94        16
#       Powell       0.98      1.00      0.99        47
#     Rumsfeld       0.96      0.96      0.96        24
#         Bush       0.99      0.98      0.99       106
#    Schroeder       0.92      1.00      0.96        22
#       Chavez       1.00      0.93      0.96        14
#        Blair       0.96      0.93      0.95        29
#
#     accuracy                           0.97       258
#    macro avg       0.96      0.96      0.96       258
# weighted avg       0.97      0.97      0.97       258
# ✅ Final Test Accuracy: 97.29% (Target was 90%)
